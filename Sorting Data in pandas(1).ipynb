# %%
import pandas as pd
schema_df = pd.read_csv(r"C:\Users\amand\Desktop\pandas\survey_results_schema.csv")
df_a = pd.read_csv(r"C:\Users\amand\Desktop\pandas\survey_results_public.csv")
people = {"Name":["aman","desk","demo","Adam"],
          "last_name":["aa","dd","de","Doe"],
           "email":["aa@gmail.com","dd@yandex.com","de@hotmail.com","okk@gmail.com"]}
df = pd.DataFrame(people)

# %%
df.sort_values(by = "last_name",ascending = False) #sorting data in descending form
# Out:
#    Name last_name           email
# 2  demo        de  de@hotmail.com
# 1  desk        dd   dd@yandex.com
# 0  aman        aa    aa@gmail.com
# 3  Adam       Doe   okk@gmail.com

# %%
df.sort_values(by = ["Name","last_name"],ascending = False) #first sort in ascending then descending
# Out:
#    Name last_name           email
# 1  desk        dd   dd@yandex.com
# 2  demo        de  de@hotmail.com
# 0  aman        aa    aa@gmail.com
# 3  Adam       Doe   okk@gmail.com

# %%
df.sort_index() #sorting by indexes in our Dictionary
# Out:
#    Name last_name           email
# 0  aman        aa    aa@gmail.com
# 1  desk        dd   dd@yandex.com
# 2  demo        de  de@hotmail.com
# 3  Adam       Doe   okk@gmail.com

# %%
df["last_name"].sort_values() #sorting specific cloumn in dataset
# Out:
# 3    Doe
# 0     aa
# 1     dd
# 2     de
# Name: last_name, dtype: object

# %%
df_a.sort_values(by=["Country","ConvertedComp"],ascending=[True,False],inplace = True) #sorting w.r.t two columns

# %%
df_a[["Country","ConvertedComp"]].head(100)
# Out:
#            Country  ConvertedComp
# 63925  Afghanistan      1000000.0
# 63993  Afghanistan      1000000.0
# 61540  Afghanistan      1000000.0
# 38261  Afghanistan       231192.0
# 28270  Afghanistan       130000.0
# ...            ...            ...
# 50480      Albania        15900.0
# 23409      Albania        13776.0
# 37216      Albania        12972.0
# 562        Albania        10812.0
# 27611      Albania        10596.0
#
# [100 rows x 2 columns]

# %%
df_a["ConvertedComp"].nlargest(100) #get largest salaries
# Out:
# 53175    2000000.0
# 5701     2000000.0
# 42657    2000000.0
# 58136    2000000.0
# 45753    2000000.0
# 1784     2000000.0
# 3058     2000000.0
# 3031     2000000.0
# 1407     2000000.0
# 3247     2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df_a.nlargest(100,"ConvertedComp") #all info about nlargest salaries data
# Out:
#        Respondent                      MainBranch Hobbyist   Age  \
# 53175       54263  I am a developer by profession      Yes  29.0
# 5701         5725  I am a developer by profession       No  26.0
# 42657       43430  I am a developer by profession      Yes  33.0
# 58136       59279  I am a developer by profession      Yes   NaN
# 45753       46711  I am a developer by profession      Yes   NaN
# ...           ...                             ...      ...   ...
# 63890       65341  I am a developer by profession      Yes   NaN
# 663           665  I am a developer by profession      Yes  24.0
# 60582       61798  I am a developer by profession      Yes  28.0
# 58177       59321  I am a developer by profession      Yes  43.0
# 4011         4027  I am a developer by profession      Yes  29.0
#
#                  Age1stCode CompFreq     CompTotal  ConvertedComp  \
# 53175                    10   Weekly  7.000000e+04      2000000.0
# ...
