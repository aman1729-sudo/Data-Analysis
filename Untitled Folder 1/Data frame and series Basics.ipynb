# %%
import pandas as pd

# %%
schema_df = pd.read_csv(r"C:\Users\amand\Desktop\pandas\survey_results_schema.csv")
df = pd.read_csv(r"C:\Users\amand\Desktop\pandas\survey_results_public.csv")

# %%
pd.set_option('display.max_columns',80)
pd.set_option('display.max_columns',80)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
#data frames are rows and columns on which we can operate
people = {"Name":["aman","desk","demo"],
          "last_name":["aa","dd","de"],
           "email":["aa@gmail.com","dd@yandex.com","de@hotmail.com"]}

# %%
df_p = pd.DataFrame(people) #converting dictionary data to data frame

# %%
df_p
# Out:
#    Name last_name           email
# 0  aman        aa    aa@gmail.com
# 1  desk        dd   dd@yandex.com
# 2  demo        de  de@hotmail.com

# %%
df_p["email"] #get special columns
# Out:
# 0      aa@gmail.com
# 1     dd@yandex.com
# 2    de@hotmail.com
# Name: email, dtype: object

# %%
type(df_p["email"]) #series is row of single columns
# Out:
# pandas.core.series.Series

# %%
df_p[["last_name","email"]]#get multiple columns and its not a series because series is single column list
# Out:
#   last_name           email
# 0        aa    aa@gmail.com
# 1        dd   dd@yandex.com
# 2        de  de@hotmail.com

# %%
df_p.columns #get all columns
# Out:
# Index(['Name', 'last_name', 'email'], dtype='object')

# %%
df_p.iloc[0] #acessing first row using iloc(integer location)
# Out:
# Name                 aman
# last_name              aa
# email        aa@gmail.com
# Name: 0, dtype: object

# %%
df_p.iloc[[0,1]] #acsessing multiple rows
# Out:
#    Name last_name          email
# 0  aman        aa   aa@gmail.com
# 1  desk        dd  dd@yandex.com

# %%
df_p.iloc[[0,1],2] #acessing rows and columns simultaneosly
# Out:
# 0     aa@gmail.com
# 1    dd@yandex.com
# Name: email, dtype: object

# %%
df_p.loc[[0,1],["email","last_name"]] #acess by loc
# Out:
#            email last_name
# 0   aa@gmail.com        aa
# 1  dd@yandex.com        dd

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df["Hobbyist"].value_counts() #series of hobbyist and check yes and no
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:2,["Hobbyist"]] #slicing rows with Hobbyist column
# Out:
#   Hobbyist
# 0      Yes
# 1       No
# 2      Yes

# %%
df.loc[0:2,"Hobbyist":"Employment"]
# Out:
#   Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes  NaN         13  Monthly        NaN            NaN
# 1       No  NaN         19      NaN        NaN            NaN
# 2      Yes  NaN         15      NaN        NaN            NaN
#
#               Country    CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0             Germany   European Euro            EUR   Microsoft SQL Server
# 1      United Kingdom  Pound sterling            GBP                    NaN
# 2  Russian Federation             NaN            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
#
# ...
