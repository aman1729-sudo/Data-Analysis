# %%
import pandas as pd
schema_df = pd.read_csv(r"C:\Users\amand\Desktop\pandas\survey_results_schema.csv")
df = pd.read_csv(r"C:\Users\amand\Desktop\pandas\survey_results_public.csv")

# %%
people = {"Name":["aman","desk","demo"],
          "last_name":["aa","dd","de"],
           "email":["aa@gmail.com","dd@yandex.com","de@hotmail.com"]}
df_p = pd.DataFrame(people)

# %%
filt = (df_p["last_name"] == "aa") #check last_name in data as aa

# %%
df_p[filt] #get all data that satisfy filt
# Out:
#    Name last_name         email
# 0  aman        aa  aa@gmail.com

# %%
df_p.loc[filt,"email"] #acsessing conditionals with loc
# Out:
# 0    aa@gmail.com
# Name: email, dtype: object

# %%
desk = (df_p["last_name"] == "aa") | (df_p["Name"] == "aman") #or statement , for and use &

# %%
desk
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
df_p.loc[~desk,"email"] #use ~ to get all email excluding desk's
# Out:
# 1     dd@yandex.com
# 2    de@hotmail.com
# Name: email, dtype: object

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
pd.set_option("display.max_columns",61)
pd.set_option("display.max_rows",61)

# %%
high_salary = (df["ConvertedComp"]) > 150000

# %%
df.loc[high_salary]
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 17             18  I am a developer by profession      Yes  32.0         12
# 53             54  I am a developer by profession       No  44.0          7
# 56             57  I am a developer by profession       No  44.0         12
# 64             65  I am a developer by profession      Yes  34.0         13
# 66             67  I am a developer by profession      Yes  35.0          6
# ...           ...                             ...      ...   ...        ...
# 64035       65502  I am a developer by profession      Yes   NaN         11
# 64057       65527  I am a developer by profession      Yes   NaN         11
# 64058       65528  I am a developer by profession       No   NaN         16
# 64083       65554  I am a developer by profession      Yes   NaN         13
# 64113       65586  I am a developer by profession      Yes   NaN          8
#
# ...

# %%
df.loc[high_salary,["Country","LanguageWorkedWith"]]
# Out:
#              Country                                 LanguageWorkedWith
# 17     United States                Bash/Shell/PowerShell;HTML/CSS;Perl
# 53     United States                             C#;HTML/CSS;JavaScript
# 56     United States                                             C#;VBA
# 64     United States   Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;SQL
# 66     United States                           HTML/CSS;JavaScript;Ruby
# ...              ...                                                ...
# 64035  United States  C#;HTML/CSS;JavaScript;Perl;Python;SQL;TypeScript
# 64057  United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 64058         Canada                                             Python
# 64083  United States                                                NaN
# 64113  United States                                                NaN
#
# [3763 rows x 2 columns]

# %%
countries = ["United States","India"] #use many cases together
filt = df["Country"].isin(countries)

# %%
df.loc[filt,"Country"]
# Out:
# 4        United States
# 6                India
# 7        United States
# 13       United States
# 16       United States
#              ...
# 64439            India
# 64442            India
# 64443    United States
# 64452            India
# 64456    United States
# Name: Country, Length: 20872, dtype: object

# %%
temp = (df["LanguageWorkedWith"] == "Python")

# %%
fil = df["LanguageWorkedWith"].str.contains("Python",na = False) #different method to check python

# %%
fil
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 64456    False
# 64457     True
# 64458    False
# 64459    False
# 64460    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %%
df.loc[fil]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 2               3                        I code primarily as a hobby      Yes
# 7               8                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 12             13  I am not primarily a developer, but I write co...      Yes
# 14             15             I am a student who is learning to code      Yes
# ...           ...                                                ...      ...
# 64433       61561                                                NaN      Yes
# 64438       62391                                                NaN      Yes
# 64443       63077                                                NaN      Yes
# 64446       63640                                                NaN      Yes
# 64457       64867                                                NaN      Yes
#
# ...
