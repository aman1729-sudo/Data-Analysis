# %%
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\amand\.spyder-py3\deta.csv")
data.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
age = data["Age"]
all_sal = data["All_Devs"]
py_sal = data["Python"]
js_sal = data["JavaScript"]
plt.plot(age,all_sal,label = "All devs")
plt.plot(age,py_sal,label = "Python devs")
plt.fill_between(age,py_sal,alpha= 0.25)
plt.legend()

# %%
plt.plot(age,all_sal,label = "All devs")
median_sal = 57287
plt.fill_between(age,py_sal,median_sal,
                 where=(py_sal > medain_sal),
                 interpolate = True,
                 alpha= 0.25)

# %%
plt.plot(age,all_sal,label = "All devs")
median_sal = 57287
plt.fill_between(age,py_sal,median_sal,
                 where=(py_sal < medain_sal),
                 interpolate = True,
                 color = "red",
                 alpha= 0.25)

# %%
plt.plot(age,all_sal,label = "All devs")
median_sal = 57287
plt.fill_between(age,py_sal,median_sal,
                 where=(py_sal > medain_sal),
                 interpolate = True,
                 label = "Above Median",
                 alpha= 0.25)
plt.plot(age,all_sal,label = "All devs")
median_sal = 57287
plt.fill_between(age,py_sal,median_sal,
                 where=(py_sal < medain_sal),
                 label = "BElow medain",
                 interpolate = True,
                 color = "red",
                 alpha= 0.25)
plt.fill_between(age,py_sal,median_sal,
                 where=(py_sal == medain_sal),
                 interpolate = True,
                 color = "green",
                 alpha= 0.25)
plt.legend()
