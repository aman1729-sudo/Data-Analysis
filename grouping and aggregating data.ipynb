# %%
import pandas as pd
schema_df = pd.read_csv(r"C:\Users\amand\Desktop\pandas\survey_results_schema.csv")
df = pd.read_csv(r"C:\Users\amand\Desktop\pandas\survey_results_public.csv")

# %%
pd.set_option("display.max_columns",85)
pd.set_option("display.max_rows",80)

# %%
df["ConvertedComp"].median() #median salary ang ignore NaN vals
# Out:
# 54049.0

# %%
df.median()
# Out:
# Respondent       32231.0
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe() #count are non NA rows
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df["ConvertedComp"].count() # 34756 left salary section empty
# Out:
# 34756

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df["NEWLearn"].value_counts() #count specific question answer
# Out:
# Every few months        20938
# Once a year             20693
# Once every few years    13284
# Once a decade            1241
# Name: NEWLearn, dtype: int64

# %%
df["NEWLearn"].value_counts(normalize = True) #normailize data
# Out:
# Every few months        0.372854
# Once a year             0.368491
# Once every few years    0.236555
# Once a decade           0.022099
# Name: NEWLearn, dtype: float64

# %%
df["Country"].value_counts()
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Marshall Islands        1
# Lesotho                 1
# Nauru                   1
# Liechtenstein           1
# Gabon                   1
# Name: Country, Length: 183, dtype: int64

# %%
cntry_grp = df.groupby(["Country"]) #grouping rows by country

# %%
cntry_grp.get_group("India") #survey results from india
# Out:
# Every few months        3546
# Once a year             2223
# Once every few years     883
# Once a decade            113
# Name: NEWLearn, dtype: int64

# %%
cntry_grp.get_group("India")["NEWLearn"].value_counts()
# Out:
# Every few months        3546
# Once a year             2223
# Once every few years     883
# Once a decade            113
# Name: NEWLearn, dtype: int64

# %%
cntry_grp["NEWLearn"].value_counts().head(50) #most popular learning method
# Out:
# Country      NEWLearn
# Afghanistan  Every few months         26
#              Once a year              19
#              Once every few years      6
# Albania      Every few months         17
#              Once a year              11
#              Once every few years      8
#              Once a decade             3
# Algeria      Every few months         37
#              Once a year              29
#              Once every few years      8
#              Once a decade             4
# Andorra      Once every few years      3
#              Every few months          2
#              Once a year               2
#              Once a decade             1
# Angola       Once a year               3
#              Once every few years      1
# Argentina    Every few months        163
#              Once a year             111
#              Once every few years     66
#              Once a decade             4
# Armenia      Once a year              22
# ...

# %%
cntry_grp["NEWLearn"].value_counts().loc["India"] #get any data coilumn of any country
# Out:
# NEWLearn
# Every few months        3546
# Once a year             2223
# Once every few years     883
# Once a decade            113
# Name: NEWLearn, dtype: int64

# %%
cntry_grp["ConvertedComp"].median() #medain salary of all contries
# Out:
# 10056.0

# %%
cntry_grp["ConvertedComp"].median().loc["India"]
# Out:
# 10056.0

# %%
cntry_grp["ConvertedComp"].agg(["median","mean"]) #medain and mean salary for countries
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
filt = df["Country"] == "India" #people from india worked with python
df.loc[filt]["LanguageWorkedWith"].str.contains("Python").sum()
# Out:
# 2670

# %%
cntry_grp["LanguageWorkedWith"].apply((lambda x :x.str.contains("Python").sum() * 100))/ df["Country"].value_counts() #% of people using python in countries
# Out:
# Afghanistan                             13.095238
# Albania                                 24.074074
# Algeria                                 42.553191
# Andorra                                 23.076923
# Angola                                  11.111111
#                                           ...
# Venezuela, Bolivarian Republic of...    41.428571
# Viet Nam                                28.021978
# Yemen                                   14.285714
# Zambia                                  19.047619
# Zimbabwe                                41.935484
# Length: 183, dtype: float64

# %%
country_respodents = df["Country"].value_counts()
country_uses_python = df["LanguageWorkedWith"] == "Python"
python_df = pd.concat([country_respodents,country_uses_python],axis = "columns",sort = False)

# %%
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...
